# %% [markdown]
# <a href="https://colab.research.google.com/github/giuliano-st/ContabilidadeAplicadaaInformatica/blob/main/Contabilidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

def ler_planilha(caminho):
    df = pd.read_excel(caminho, names=['nome', 'tipo', 'valor'], skiprows=2)

    return df.to_dict(orient='records')

def classificar_conta(contas):
    balanco = { #Dicionário das contas
        "ativo" : [],
        "passivo" : []
    }
    palavras_passivo = ["financiamento", "empréstimo", "contas a pagar", "fornecedores", "salários"]
    palavras_ativo = ["caixa", "banco", "aplicações", "clientes", "estoque",
                "cartões", "móveis", "máquinas", "veículos", "softwares", "imóveis"]
    for conta in contas:
      nome = str(conta["nome"]).lower()

      if any(p in nome for p in palavras_passivo):
          conta["tipo"] = "passivo"
          balanco['passivo'].append(conta)

      elif any(p in nome for p in palavras_ativo):
          conta["tipo"] = "ativo"
          balanco['ativo'].append(conta)

      else:
          conta["tipo"] = "passivo"
          balanco['passivo'].append(conta)

    return balanco

def somar_balanco(balanco_total):
    total_ativos = sum(item["valor"] for item in balanco_total['ativo'])
    total_passivos = sum(item["valor"] for item in balanco_total['passivo'])

    patrimonio_liquido = total_ativos - total_passivos
    print(f"Balanço: ")
    print(f"Total Ativo:  R$ {total_ativos:,.2f}")
    print(f"Total Passivo: R$ {total_passivos:,.2f}")
    print(f"Patrimônio Líquido: R$ {(total_ativos - total_passivos):,.2f}")


def main():
  caminho = "Contas.xlsx"
  lista_bruta = ler_planilha(caminho)
  balanco_final = classificar_conta(lista_bruta)
  print(f"Contas:")
  for item in lista_bruta:
    print(f"{item["nome"], item["tipo"], item["valor"]}")
  somar_balanco(balanco_final)
if __name__ == "__main__":
  main()
# Out:
# Contas:
# ('1. Caixa e Bancos', 'ativo', 25000)
# ('2. Aplicações Financeiras ', 'ativo', 15000)
# ('3. Clientes a Receber', 'ativo', 58000)
# ('4. Estoque de Produtos ', 'ativo', 72000)
# ('5. Cartões a Receber', 'ativo', 10000)
# ('6. Móveis e Utensílios ', 'ativo', 5000)
# ('7. Máquinas e Equipamentos', 'ativo', 150000)
# ('8. Veículos', 'ativo', 85000)
# ('9. Softwares e Marcas', 'ativo', 40000)
# ('10. Imóveis', 'ativo', 20000)
# ('11. Fornecedores Nacionais', 'passivo', 45000)
# ('12. Empréstimos Bancários', 'passivo', 32000)
# ('13. Salários e Encargos a Pagar', 'passivo', 22500)
# ('14. Impostos a Recolher', 'passivo', 12000)
# ('15. Dividendos a Pagar', 'passivo', 8500)
# ('16. Financiamento de Veículos ', 'passivo', 60000)
# ('17. Empréstimos de Sócios ', 'passivo', 50000)
# ('18. Capital Social ', 'passivo', 200000)
# ('19. Fornecedor Internacional', 'passivo', 30000)
# ('20. Lucros Acumulados', 'passivo', 20000)
# Balanço:
# Total Ativo:  R$ 480,000.00
# Total Passivo: R$ 480,000.00
# Patrimônio Líquido: R$ 0.00

# %%
import pandas as pd

def ler_planilha(caminho):
    df = pd.read_excel(caminho, names=['conta contabil', 'valor', 'classificacao'], skiprows=1)

    return df.to_dict(orient='records')

def classificar_conta(contas):
    balanco = { #Dicionário das contas
        "receita" : [],
        "despesa" : [],
        "outros": []
    }
    palavras_passivo = ["despesa", "imposto", "custo", "estorno"]
    palavras_ativo = ["receita"]
    palavras_outros = ["outros"]
    for conta in contas:
      nome = str(conta["classificacao"]).lower()

      if any(p in nome for p in palavras_passivo):
          conta["classificacao"] = "despesa"
          balanco['despesa'].append(conta)

      if any(p in nome for p in palavras_ativo):
          conta["classificacao"] = "receita"
          balanco['receita'].append(conta)

      if any(p in nome for p in palavras_outros):
          conta["classificacao"] = "outros"
          balanco['outros'].append(conta)

    return balanco

def somar_balanco(balanco_total):
    total_ativos = sum(item["valor"] for item in balanco_total['receita'])
    total_passivos = sum(item["valor"] for item in balanco_total['despesa'])
    total_outros = sum(item["valor"] for item in balanco_total['outros'])

    patrimonio_liquido = total_ativos - total_passivos
    print(f"Balanço: ")
    print(f"Total Ativo:  R$ {total_ativos:,.2f}")
    print(f"Total Passivo: R$ {total_passivos:,.2f}")
    print(f"Total Outros: R$ {total_outros:,.2f}")
    print(f"Resultado operacional: R$ {(total_ativos + total_passivos):,.2f}")
    print(f"Resultado Líquido: R$ {(total_ativos + total_passivos + total_outros):,.2f}")


def main():
  caminho = "Contas.xlsx"
  lista_bruta = ler_planilha(caminho)
  balanco_final = classificar_conta(lista_bruta)
  print(f"Contas:")
  for item in lista_bruta:
    print(f"{item["conta contabil"], item["valor"], item["classificacao"]}")
  somar_balanco(balanco_final)
if __name__ == "__main__":
  main()
# Out:
# Contas:
# ('1. Receita Bruta de Vendas', 450000, 'receita')
# ('2. (-) Devoluções de Vendas', -12000, 'despesa')
# ('3. (-) ICMS sobre Vendas', -81000, 'despesa')
# ('4. (-) PIS/COFINS sobre Vendas', -16500, 'despesa')
# ('5. (-) Custo das Mercadorias Vendidas (CMV)', -180000, 'despesa')
# ('6. Salários e Ordenados', -45000, 'despesa')
# ('7. Encargos Sociais (FGTS/INSS)', -12500, 'despesa')
# ('8. Aluguel de Imóveis', -8000, 'despesa')
# ('9. Energia Elétrica e Água', -3200, 'despesa')
# ('10. Despesas com Marketing', -15000, 'despesa')
# ('11. Comissões de Vendedores', -9000, 'despesa')
# ('12. Fretes sobre Vendas', -4500, 'despesa')
# ('13. Despesas com Manutenção', -2800, 'despesa')
# ('14. Depreciação e Amortização', -5500, 'despesa')
# ('15. Receitas Financeiras (Juros Ativos)', 2100, 'receita')
# ('16. Despesas Financeiras (Juros Passivos)', -3800, 'despesa')
# ('17. Despesas Bancárias e Tarifas', -1200, 'despesa')
# ('18. Outras Receitas Operacionais', 4000, 'receita')
# ('19. Provisão para IRPJ', -8400, 'outros')
# ('20. Provisão para CSLL', -3050, 'outros')
# Balanço:
# Total Ativo:  R$ 456,100.00
# Total Passivo: R$ -400,000.00
# Total Outros: R$ -11,450.00
# Resultado operacional: R$ 56,100.00
# Resultado Líquido: R$ 44,650.00
