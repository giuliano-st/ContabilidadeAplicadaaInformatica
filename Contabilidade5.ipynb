# %% [markdown]
# <a href="https://colab.research.google.com/github/giuliano-st/ContabilidadeAplicadaaInformatica/blob/main/Contabilidade5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

def ler_planilha(caminho):
    df = pd.read_excel(caminho, names=["gasto", "valor", "classificacao"],index_col=0)
    df["valor"] = df["valor"].astype(str)
    df["valor"] = (
        df["valor"].str.replace("R$", "", regex=False).str.replace(" por unidade", "", regex=False).str.strip())
    df["valor"] = df["valor"].str.replace(".", "", regex=False)
    df["valor"] = df["valor"].str.replace(",", ".", regex=False)
    df["valor"] = pd.to_numeric(df["valor"], errors="coerce").fillna(0)
    return df.to_dict(orient="records")

def classificar_conta(contas):
    balanco = {
        "variavel" : [],
        "fixo" : [],
        "despesa" : []
    }
    palavras_fixo = ["fixo", "fixa"]
    palavras_variavel = ["variavel"]
    palavras_despesa = ["despesa"]

    for conta in contas:
        nome = str(conta["classificacao"]).lower()

        if any(p in nome for p in palavras_fixo):
            balanco['fixo'].append(conta)

        elif any(p in nome for p in palavras_variavel):
            balanco['variavel'].append(conta)

        elif any(p in nome for p in palavras_despesa):
            balanco['despesa'].append(conta)

    return balanco

def somar_balanco(balanco_total):
    valor_contrato = 15000
    total_fixos = sum(item["valor"] for item in balanco_total['fixo'])
    total_variavel = sum(item["valor"] for item in balanco_total['variavel'])
    total_despesa = sum(item["valor"] for item in balanco_total['despesa'])
    custo_total = total_variavel + total_fixos + total_despesa

    mc = valor_contrato - total_variavel
    imc = mc / valor_contrato
    pec = total_fixos / imc
    imc = imc * 100

    print(f"Dados: ")
    print(f"Custo Fixo Total:  R$ {total_fixos:,.2f}")
    print(f"Custo Variável:  R$ {total_variavel:,.2f}")
    print(f"Custo Total: R$ {custo_total:,.2f}")
    print(f"Margem de Constribuição: R$ {mc:,.2f}")
    print(f"Ponto de Equilibrio Contábil: {pec:,.2f}")
    print(f"Ponto de Equlibrio Contábil (em porcentagem): {imc:,.2f}%")

def main():
    caminho = "Dados Custos.xlsx"
    lista_bruta = ler_planilha(caminho)
    balanco_final = classificar_conta(lista_bruta)
    print(f"Contas:")
    for item in lista_bruta:
        print(f"{item["gasto"], item["valor"], item["classificacao"]}")
    somar_balanco(balanco_final)

if __name__ == "__main__":
    main()
# Out:
# Contas:
# ('Salário da equipe de programadores (dedicados ao serviço)', 7000.0, 'Custo Fixo')
# ('Comissão de 5% sobre o valor do serviço para o vendedor', 750.0, 'Despesa Variavel')
# ('Estagiário para o administrativo ', 1200.0, 'Despesa Fixa')
# ('Licenças de software de desenvolvimento (pagas por usuário ativo)', 800.0, 'Custo Variavel')
# ('Imposto sobre Serviços (ISS) de 10% sobre o faturamento', 1500.0, 'Despesa Variavel')
# ('Pró-labore do Lucas (Sócio-Administrador)', 3000.0, 'Despesa Fixa')
# ('Conta de internet dedicada da empresa', 250.0, 'Custo Fixo')
# ('Material de escritório e limpeza', 150.0, 'Despesa Fixa')
# ('Plataforma de automação de chamados', 800.0, 'Custo Fixo')
# Dados:
# Custo Fixo Total:  R$ 12,400.00
# Custo Variável:  R$ 3,050.00
# Custo Total: R$ 15,450.00
# Margem de Constribuição: R$ 11,950.00
# Ponto de Equilibrio Contábil: 15,564.85
# Ponto de Equlibrio Contábil (em porcentagem): 79.67%
